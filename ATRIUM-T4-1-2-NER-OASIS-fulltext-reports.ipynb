# %% [markdown]
# ## Running ATRIUM NER pipeline on full text extracted from OASIS PDF reports

# %%
# %%capture

import warnings
# suppress user warnings during execution
warnings.filterwarnings(action='ignore', category=UserWarning)

# load required dependencies
# %pip install --upgrade pip
# %pip install spacy
# %pip install ipywidgets
# %sx python -m spacy download en_core_web_sm

# %%
import spacy # for NER processing
#from spacy.tokens import Doc # for NER results
from datetime import datetime as DT # for timestamps
import json, os
from slugify import slugify # for valid filenames from identifiers
from weasyprint import HTML
#from rematch2 import PeriodoRuler, VocabularyRuler, NegationRuler, DocSummary, TextNormalizer
from rematch2 import DocSummary
from rematch2.spacypatterns import patterns_en_ATTRIBUTE_RULES # rules to override POS tags in some cases

# using predefined spaCy pipeline (English)
print("loading spacy language model")
nlp = spacy.load("en_core_web_sm", disable = ['ner'])
print("..done")
# adding custom rules to override default POS tagging for specific cases
# NOTE: adding rules to existing attribute_ruler component didn't seem to
# work, so inserting another one directly after it and adding rules to that
#nlp.get_pipe("attribute_ruler").add_patterns(patterns_en_ATTRIBUTE_RULES)
print("adding attribute ruler")
ar = nlp.add_pipe("attribute_ruler", name="custom_attribute_ruler", after="attribute_ruler")
ar.add_patterns(patterns_en_ATTRIBUTE_RULES)
print("..done")

# using HE Periods list
periodo_authority_id = "p0kh9ds" 

# reading supplementary lists from JSON files
def read_json(file_name):
    data = []
    try:
        with open(file_name, "r") as f:
            data = json.load(f)
    except Exception as e:
        print(f"Problem reading \"{file_name}\": {e}")
    return data

print("reading supplementary lists")
supp_list_obj = read_json("./supp_list_en_FISH_ARCHOBJECTS.json")
supp_list_mon = read_json("./supp_list_en_FISH_MONUMENTS.json")
supp_list_per = read_json("./supp_list_en_FISH_PERIODS.json")
print("..done")

# lists of vocabulary concepts we don't want to appear in the results even if legitimately matches 
# stop list is hardcoded directly here, but should also be read in from JSON files as above
stop_list_mon = [
    "http://purl.org/heritagedata/schemes/eh_tmt2/concepts/71054",  # Roundhouse (Lock Up)
    "http://purl.org/heritagedata/schemes/eh_tmt2/concepts/93179",  # Roundhouse (Railway)
    "http://purl.org/heritagedata/schemes/eh_tmt2/concepts/69434",  # works
    "http://purl.org/heritagedata/schemes/eh_tmt2/concepts/92230",  # term
    "http://purl.org/heritagedata/schemes/eh_tmt2/concepts/93931",  # model
    "http://purl.org/heritagedata/schemes/eh_tmt2/concepts/88215",  # half moon
    "http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68762",  # crest
]

stop_list_obj = [
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/139085", # Coin (Contemporary Imitation)
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/139087", # Coin (Modern Forgery)
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/139086", # Coin (Modern Imitation)
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/95353",  # level
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/95306",  # scale
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/96615",  # shift
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/96379",  # point
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/143243", # setting
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/96735",  # staff
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/100151", # paper
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/96473",  # model
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/100107", # desk
    "http://purl.org/heritagedata/schemes/mda_obj/concepts/95183",  # crest
]

# add rematch2 NER component(s) to the pipeline
nlp.add_pipe("normalize_text", before = "tagger")

nlp.add_pipe("yearspan_ruler", last=True)   
nlp.add_pipe("periodo_ruler", last=True, config={"periodo_authority_id": periodo_authority_id, "supp_list": supp_list_per}) 
nlp.add_pipe("fish_archobjects_ruler", last=True, config={"supp_list": supp_list_obj, "stop_list": stop_list_obj}) 
nlp.add_pipe("fish_monument_types_ruler", last=True, config={"supp_list": supp_list_mon, "stop_list": stop_list_mon})   
nlp.add_pipe("negation_ruler", last=True) 
nlp.add_pipe("child_span_remover", last=True) 

input_directory = "./data/journals_july_2024/text extraction - new"

# subset of files to process
file_names = [
    "120_031_097_new.txt",
    "2022_96_001_012_cooper_garton_new.txt",
    "2022_96_013-068_huxley_new.txt",
    "archael547-005-040-breeze_new.txt",
    "archael547-079-116-ceolwulf_new.txt",
    "daj_v023_1901_040-047_new.txt",
    "daj_v086_1966_031-053_new.txt",
    "nas_20_1985_67-86_jackson_new.txt",
    "nas_20_1985_87-112_taylor_new.txt",
    "surreyac103_063-090_lambert_new.txt"
]

# timestamp for use in directory names
timestamp = DT.now().strftime('%Y%m%d')   

# create output file path if it does not already exist
output_directory = os.path.join(input_directory, f"ner-output-{timestamp}")
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

counter = 0
print("scanning input file directory")
for entry in os.scandir(input_directory):        
    counter += 1
    # temp break for testing
    #if counter > 2: 
        #break
    
    #if entry.is_file() and entry.name.endswith(".txt"): 
    if entry.is_file() and entry.name.lower() in file_names:    
        ts_started = DT.now()   

        # print progress indicator
        input_file_name = entry.name        
        print(f"processing entry {counter} - '{input_file_name}'")

        # read text contents of input file
        print(f"reading {input_file_name}")
        input_file_text = ""
        with open(entry.path) as input_file:
            input_file_text = input_file.read()
        print(f"read '{input_file_name}' in {DT.now() - ts_started}ms")
        
        # set up metadata to include in output
        metadata = {
            "identifier": input_file_name,
            "title": "vocabulary-based NER results",
            "description": "vocabulary-based NER annotation on report full-text",
            "creator": "T4-1-2-NER-OASIS-reports-full-text.ipynb",
            "periodo_authority_id": periodo_authority_id,
            "ner_pipeline": nlp.pipe_names,
            "input_file_name": input_file_name,
            "input_record_count": 1
        }

        # perform annotation on input text
        ts_nlp = DT.now() 
        print("running nlp pipeline") 
        doc = nlp(input_file_text)
        print(f"finished nlp pipeline in {DT.now() - ts_nlp}")

        ts_sum = DT.now() 
        print("summarizing results") 
        summary = DocSummary(doc, metadata=metadata)
        print(f"finished summarizing results in {DT.now() - ts_sum}")
        
        ts_finished = DT.now()

        metadata["starting"] = ts_started.strftime('%Y-%m-%dT%H:%M:%SZ')
        metadata["finished"] = ts_finished.strftime('%Y-%m-%dT%H:%M:%SZ')
        metadata["duration"] =  ts_finished - ts_started

        # write results to text files
        #html_file_name = os.path.join(output_directory, f"ner-output-{slugify(input_file_name)}.html") 
        text_file_name = os.path.join(output_directory, f"ner-output-{slugify(input_file_name)}.txt")
        json_file_name = os.path.join(output_directory, f"ner-output-{slugify(input_file_name)}.json")
        pdf_file_name= os.path.join(output_directory, f"ner-output-{slugify(input_file_name)}.pdf")
        
        # note last run took 21 mins for 2 files
        # 10/07/25 - now 1:10:31 for 10 files (JSON, TEXT and HTML output)
        ts_started = DT.now()   
        print("creating PDF report")
        report = summary.report(format="html")      
        #with open(html_file_name, "w") as file:
            #file.write(report)
        report = summary.report(format="html")      
        HTML(None, string=report, encoding="utf-8").write_pdf(target=pdf_file_name)
                
        print(f"finished creating PDF report in {DT.now() - ts_started}")

        #ts_started = DT.now()
        #print("creating TEXT report")
        #report = summary.report(format="text")
        #with open(text_file_name, "w") as file:
            #file.write(report)
        #print(f"finished creating TEXT report in {DT.now() - ts_started}")
             
        ts_started = DT.now()
        print("creating JSON report")
        report = summary.report(format="json")
        with open(json_file_name, "w") as file:
            file.write(report) 
        print(f"finished creating JSON report in {DT.now() - ts_started}")
# Out:
# loading spacy language model
# ..done
# adding attribute ruler
# ..done
# reading supplementary lists
# ..done
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# ordinal_ruler
# ...
# "get_negated_span_pairs" ran in 110.499 seconds
# "report_to_html" ran in 224.513 seconds
# "report" ran in 224.513 seconds
# "report_to_html" ran in 3.499 seconds
# "report" ran in 3.499 seconds
# finished creating PDF report in 0:03:57.069862
# creating JSON report
# "report_to_json" ran in 0.714 seconds
# "report" ran in 0.714 seconds
# finished creating JSON report in 0:00:00.716705
# processing entry 29 - 'surreyac103_063-090_lambert_new.txt'
# reading surreyac103_063-090_lambert_new.txt
# read 'surreyac103_063-090_lambert_new.txt' in 0:00:00.001559ms
# running nlp pipeline
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 31.616 seconds
# "_get_noun_chunk_pairs" ran in 3.276 seconds
# "_get_pairs" ran in 34.892 seconds
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 58.553 seconds
# "_get_noun_chunk_pairs" ran in 6.098 seconds
# "_get_pairs" ran in 64.651 seconds
# finished nlp pipeline in 0:06:49.097550
# summarizing results
# finished summarizing results in 0:00:00.002740
# creating PDF report
# "_get_dependency_pairs2" ran in 27.305 seconds
# "_get_noun_chunk_pairs" ran in 2.828 seconds
# "_get_pairs" ran in 30.133 seconds
# "get_span_pairs" ran in 30.133 seconds
# "_get_dependency_pairs2" ran in 26.818 seconds
# "_get_noun_chunk_pairs" ran in 2.909 seconds
# "_get_pairs" ran in 29.727 seconds
# "get_negated_span_pairs" ran in 29.727 seconds
# "report_to_html" ran in 60.830 seconds
# "report" ran in 60.830 seconds
# "report_to_html" ran in 0.929 seconds
# "report" ran in 0.929 seconds
# finished creating PDF report in 0:01:08.633014
# creating JSON report
# "report_to_json" ran in 0.084 seconds
# "report" ran in 0.084 seconds
# finished creating JSON report in 0:00:00.084793
# processing entry 36 - 'DAJ_v086_1966_031-053_new.txt'
# reading DAJ_v086_1966_031-053_new.txt
# read 'DAJ_v086_1966_031-053_new.txt' in 0:00:00.001245ms
# running nlp pipeline
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 9.850 seconds
# "_get_noun_chunk_pairs" ran in 1.058 seconds
# "_get_pairs" ran in 10.909 seconds
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 18.424 seconds
# "_get_noun_chunk_pairs" ran in 2.104 seconds
# "_get_pairs" ran in 20.528 seconds
# finished nlp pipeline in 0:02:21.775983
# summarizing results
# finished summarizing results in 0:00:00.002388
# creating PDF report
# "_get_dependency_pairs2" ran in 8.572 seconds
# "_get_noun_chunk_pairs" ran in 1.007 seconds
# "_get_pairs" ran in 9.579 seconds
# "get_span_pairs" ran in 9.579 seconds
# "_get_dependency_pairs2" ran in 8.420 seconds
# "_get_noun_chunk_pairs" ran in 1.041 seconds
# "_get_pairs" ran in 9.461 seconds
# "get_negated_span_pairs" ran in 9.461 seconds
# "report_to_html" ran in 19.378 seconds
# "report" ran in 19.378 seconds
# "report_to_html" ran in 0.324 seconds
# "report" ran in 0.324 seconds
# finished creating PDF report in 0:00:23.665351
# creating JSON report
# "report_to_json" ran in 0.050 seconds
# "report" ran in 0.051 seconds
# finished creating JSON report in 0:00:00.051238
# processing entry 41 - 'archael547-079-116-ceolwulf_new.txt'
# reading archael547-079-116-ceolwulf_new.txt
# read 'archael547-079-116-ceolwulf_new.txt' in 0:00:00.125164ms
# running nlp pipeline
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 48.619 seconds
# "_get_noun_chunk_pairs" ran in 5.751 seconds
# "_get_pairs" ran in 54.370 seconds
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 89.636 seconds
# "_get_noun_chunk_pairs" ran in 11.044 seconds
# "_get_pairs" ran in 100.680 seconds
# finished nlp pipeline in 0:18:43.048260
# summarizing results
# finished summarizing results in 0:00:00.001637
# creating PDF report
# "_get_dependency_pairs2" ran in 40.013 seconds
# "_get_noun_chunk_pairs" ran in 5.059 seconds
# "_get_pairs" ran in 45.072 seconds
# "get_span_pairs" ran in 45.072 seconds
# "_get_dependency_pairs2" ran in 40.228 seconds
# "_get_noun_chunk_pairs" ran in 4.914 seconds
# "_get_pairs" ran in 45.142 seconds
# "get_negated_span_pairs" ran in 45.142 seconds
# "report_to_html" ran in 91.547 seconds
# "report" ran in 91.548 seconds
# "report_to_html" ran in 1.521 seconds
# "report" ran in 1.521 seconds
# finished creating PDF report in 0:01:39.423185
# creating JSON report
# "report_to_json" ran in 0.176 seconds
# "report" ran in 0.176 seconds
# finished creating JSON report in 0:00:00.177998
# processing entry 48 - 'NAS_20_1985_67-86_Jackson_new.txt'
# reading NAS_20_1985_67-86_Jackson_new.txt
# read 'NAS_20_1985_67-86_Jackson_new.txt' in 0:00:00.000364ms
# running nlp pipeline
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 13.677 seconds
# "_get_noun_chunk_pairs" ran in 1.382 seconds
# "_get_pairs" ran in 15.059 seconds
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 25.423 seconds
# "_get_noun_chunk_pairs" ran in 2.675 seconds
# "_get_pairs" ran in 28.098 seconds
# finished nlp pipeline in 0:03:35.874160
# summarizing results
# finished summarizing results in 0:00:00.003352
# creating PDF report
# "_get_dependency_pairs2" ran in 12.067 seconds
# "_get_noun_chunk_pairs" ran in 1.215 seconds
# "_get_pairs" ran in 13.282 seconds
# "get_span_pairs" ran in 13.282 seconds
# "_get_dependency_pairs2" ran in 12.173 seconds
# "_get_noun_chunk_pairs" ran in 1.311 seconds
# "_get_pairs" ran in 13.484 seconds
# "get_negated_span_pairs" ran in 13.484 seconds
# "report_to_html" ran in 27.543 seconds
# "report" ran in 27.544 seconds
# "report_to_html" ran in 0.519 seconds
# "report" ran in 0.519 seconds
# finished creating PDF report in 0:00:32.740448
# creating JSON report
# "report_to_json" ran in 0.066 seconds
# "report" ran in 0.066 seconds
# finished creating JSON report in 0:00:00.067044
# processing entry 52 - '2022_96_001_012_Cooper_Garton_new.txt'
# reading 2022_96_001_012_Cooper_Garton_new.txt
# read '2022_96_001_012_Cooper_Garton_new.txt' in 0:00:00.001083ms
# running nlp pipeline
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 3.128 seconds
# "_get_noun_chunk_pairs" ran in 0.346 seconds
# "_get_pairs" ran in 3.474 seconds
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 5.971 seconds
# "_get_noun_chunk_pairs" ran in 0.598 seconds
# "_get_pairs" ran in 6.570 seconds
# finished nlp pipeline in 0:00:56.076229
# summarizing results
# finished summarizing results in 0:00:00.001016
# creating PDF report
# "_get_dependency_pairs2" ran in 2.874 seconds
# "_get_noun_chunk_pairs" ran in 0.280 seconds
# "_get_pairs" ran in 3.154 seconds
# "get_span_pairs" ran in 3.154 seconds
# "_get_dependency_pairs2" ran in 2.793 seconds
# "_get_noun_chunk_pairs" ran in 0.290 seconds
# "_get_pairs" ran in 3.084 seconds
# "get_negated_span_pairs" ran in 3.084 seconds
# "report_to_html" ran in 6.348 seconds
# "report" ran in 6.348 seconds
# "report_to_html" ran in 0.131 seconds
# "report" ran in 0.131 seconds
# finished creating PDF report in 0:00:09.600789
# creating JSON report
# "report_to_json" ran in 0.029 seconds
# "report" ran in 0.029 seconds
# finished creating JSON report in 0:00:00.029579
# processing entry 58 - 'archael547-005-040-breeze_new.txt'
# reading archael547-005-040-breeze_new.txt
# read 'archael547-005-040-breeze_new.txt' in 0:00:00.001602ms
# running nlp pipeline
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 81.347 seconds
# "_get_noun_chunk_pairs" ran in 9.545 seconds
# "_get_pairs" ran in 90.893 seconds
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 148.727 seconds
# "_get_noun_chunk_pairs" ran in 17.327 seconds
# "_get_pairs" ran in 166.054 seconds
# finished nlp pipeline in 0:18:32.275859
# summarizing results
# finished summarizing results in 0:00:00.002265
# creating PDF report
# "_get_dependency_pairs2" ran in 65.642 seconds
# "_get_noun_chunk_pairs" ran in 7.843 seconds
# "_get_pairs" ran in 73.486 seconds
# "get_span_pairs" ran in 73.486 seconds
# "_get_dependency_pairs2" ran in 66.300 seconds
# "_get_noun_chunk_pairs" ran in 7.743 seconds
# "_get_pairs" ran in 74.043 seconds
# "get_negated_span_pairs" ran in 74.043 seconds
# "report_to_html" ran in 149.970 seconds
# "report" ran in 149.970 seconds
# "report_to_html" ran in 2.442 seconds
# "report" ran in 2.442 seconds
# finished creating PDF report in 0:02:40.914999
# creating JSON report
# "report_to_json" ran in 0.151 seconds
# "report" ran in 0.151 seconds
# finished creating JSON report in 0:00:00.152323
# processing entry 69 - '2022_96_013-068_Huxley_new.txt'
# reading 2022_96_013-068_Huxley_new.txt
# read '2022_96_013-068_Huxley_new.txt' in 0:00:00.059514ms
# running nlp pipeline
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 96.244 seconds
# "_get_noun_chunk_pairs" ran in 10.911 seconds
# "_get_pairs" ran in 107.155 seconds
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 176.946 seconds
# "_get_noun_chunk_pairs" ran in 19.560 seconds
# "_get_pairs" ran in 196.506 seconds
# finished nlp pipeline in 0:18:03.045199
# summarizing results
# finished summarizing results in 0:00:00.003581
# creating PDF report
# "_get_dependency_pairs2" ran in 78.935 seconds
# "_get_noun_chunk_pairs" ran in 8.765 seconds
# "_get_pairs" ran in 87.701 seconds
# "get_span_pairs" ran in 87.701 seconds
# "_get_dependency_pairs2" ran in 78.527 seconds
# "_get_noun_chunk_pairs" ran in 8.680 seconds
# "_get_pairs" ran in 87.207 seconds
# "get_negated_span_pairs" ran in 87.207 seconds
# "report_to_html" ran in 177.692 seconds
# "report" ran in 177.692 seconds
# "report_to_html" ran in 2.664 seconds
# "report" ran in 2.664 seconds
# finished creating PDF report in 0:03:13.935862
# creating JSON report
# "report_to_json" ran in 0.771 seconds
# "report" ran in 0.771 seconds
# finished creating JSON report in 0:00:00.772549
# processing entry 70 - 'NAS_20_1985_87-112_Taylor_new.txt'
# reading NAS_20_1985_87-112_Taylor_new.txt
# read 'NAS_20_1985_87-112_Taylor_new.txt' in 0:00:00.000714ms
# running nlp pipeline
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 27.660 seconds
# "_get_noun_chunk_pairs" ran in 2.937 seconds
# "_get_pairs" ran in 30.597 seconds
# ordinal_ruler
# dateprefix_ruler
# datesuffix_ruler
# dateseparator_ruler
# monthname_ruler
# seasonname_ruler
# yearspan_ruler
# periodo_ruler
# fish_archobjects_ruler
# fish_monument_types_ruler
# negation_ruler
# "_get_dependency_pairs2" ran in 50.899 seconds
# "_get_noun_chunk_pairs" ran in 5.303 seconds
# "_get_pairs" ran in 56.202 seconds
# finished nlp pipeline in 0:06:59.831481
# summarizing results
# finished summarizing results in 0:00:00.001999
# creating PDF report
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 167
#     165 ts_started = DT.now()
#     166 print("creating PDF report")
# --> 167 report = summary.report(format="html")
#     168 #with open(html_file_name, "w") as file:
#     169     #file.write(report)
#     170 report = summary.report(format="html")
#
# File /workspaces/rematch2/rematch2/Decorators.py:33, in run_timed.<locals>.wrapper_run_timed(*args, **kwargs)
#      29 @functools.wraps(f)
#      30 def wrapper_run_timed(*args, **kwargs):
#      31     starting = time.time()
# ---> 33     result = f(*args, **kwargs)
#      35     finished = time.time()
#      36     duration = finished - starting
#
# File /workspaces/rematch2/rematch2/DocSummary.py:217, in DocSummary.report(self, format)
#     214 @run_timed
#     215 def report(self, format: str="text") -> str:
#     216     match format.strip().lower():
# --> 217         case "html": return self.report_to_html()
#     218         case "json": return self.report_to_json()
#     219         case "text": return self.report_to_text()
#
# File /workspaces/rematch2/rematch2/Decorators.py:33, in run_timed.<locals>.wrapper_run_timed(*args, **kwargs)
#      29 @functools.wraps(f)
#      30 def wrapper_run_timed(*args, **kwargs):
#      31     starting = time.time()
# ---> 33     result = f(*args, **kwargs)
#      35     finished = time.time()
#      36     duration = finished - starting
#
# File /workspaces/rematch2/rematch2/DocSummary.py:591, in DocSummary.report_to_html(self, include_metadata, include_doctext, include_tokens, include_label_counts, include_spans, include_span_counts, include_span_pairs, include_negated_pairs)
#     589 if(include_span_counts):
#     590     output.append("<details>")
# --> 591     output.append(f"<summary class='span-counts'>Span Counts ({len(self.span_counts)})</summary>")
#     592     output.append(self.span_counts_to_html())
#     593     output.append("</details>")
#
# File /usr/local/python/3.12.1/lib/python3.12/functools.py:995, in cached_property.__get__(self, instance, owner)
#     993 val = cache.get(self.attrname, _NOT_FOUND)
#     994 if val is _NOT_FOUND:
# --> 995     val = self.func(instance)
#     996     try:
#     997         cache[self.attrname] = val
#
# File /workspaces/rematch2/rematch2/DocSummary.py:112, in DocSummary.span_counts(self)
#     110 @cached_property
#     111 def span_counts(self) -> list[SpanPairs]:
# --> 112     counts = self.get_span_counts_by_id()
#     113     return counts
#
# File /workspaces/rematch2/rematch2/DocSummary.py:324, in DocSummary.get_span_counts_by_id(self, exclude)
#     322 if span.id_:
#     323     id = span.id_
# --> 324 elif span.ent_id_:
#     325     id = span.ent_id_
#     326 elif span.lemma_:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/spacy/tokens/span.pyx:836, in spacy.tokens.span.Span.ent_id_.__get__()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/spacy/tokens/span.pyx:652, in spacy.tokens.span.Span.root.__get__()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/spacy/tokens/span.pyx:895, in spacy.tokens.span._count_words_to_root()
#
# RuntimeError: [E039] Array bounds exceeded while searching for root word. This likely means the parse tree is in an invalid state. Please report this issue here: http://github.com/explosion/spaCy/issues
