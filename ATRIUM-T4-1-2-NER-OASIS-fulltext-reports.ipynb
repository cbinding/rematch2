# %% [markdown]
# ## Running ATRIUM NER pipeline on full text extracted from OASIS PDF reports

# %%
# %%capture

import warnings
# suppress user warnings during execution
warnings.filterwarnings(action='ignore', category=UserWarning)

# load required dependencies
# %pip install --upgrade pip
# %pip install spacy
# %pip install ipywidgets
# %sx python -m spacy download en_core_web_sm

# %%
import spacy # for NER processing
#from spacy.tokens import Doc # for NER results
from datetime import datetime as DT # for timestamps
import json, os
from slugify import slugify # for valid filenames from identifiers
from weasyprint import HTML
#from rematch2 import PeriodoRuler, VocabularyRuler, NegationRuler, DocSummary, TextNormalizer
from rematch2 import DocSummary
from rematch2.spacypatterns import patterns_en_ATTRIBUTE_RULES # rules to override POS tags in some cases

# reading supplementary lists from JSON files
def read_json(file_name):
    data = []
    try:
        with open(file_name, "r") as f:
            data = json.load(f)
    except Exception as e:
        print(f"Problem reading \"{file_name}\": {e}")
    return data

# using predefined spaCy pipeline (English)
print("loading spacy language model")
nlp = spacy.load("en_core_web_sm", disable = ['ner'])
print("..done")
# adding custom rules to override default POS tagging for specific cases
# NOTE: adding rules to existing attribute_ruler component didn't seem to
# work, so insert another one directly after it and add rules to that one
print("adding attribute ruler")
# nlp.get_pipe("attribute_ruler").add_patterns(patterns_en_ATTRIBUTE_RULES) # didn't work this way
ar = nlp.add_pipe("attribute_ruler", name="custom_attribute_ruler", after="attribute_ruler")
ar.add_patterns(patterns_en_ATTRIBUTE_RULES)
print("..done")

# using "Historic England Archaeological and Cultural Periods" Perio.do authority
periodo_authority_id = "p0kh9ds" 
# read supplementary and stopword lists from JSON files
print("reading supplementary lists and stopword lists")
# supplementary concepts we want to appear in the results (or alternate terms for existing concepts)
supp_list_obj = read_json("./supp_list_en_FISH_ARCHOBJECTS.json")
supp_list_mon = read_json("./supp_list_en_FISH_MONUMENTS.json")
supp_list_per = read_json("./supp_list_en_FISH_PERIODS.json")
# existing vocabulary concepts we don't want to appear in the results (even if legitimate matches) 
stop_list_obj = read_json("./stop_list_en_FISH_ARCHOBJECTS.json")
stop_list_mon = read_json("./stop_list_en_FISH_MONUMENTS.json")
print("..done")

# add rematch2 NER component(s) to the pipeline
nlp.add_pipe("normalize_text", before = "tagger")
nlp.add_pipe("yearspan_ruler", last=True)   
nlp.add_pipe("periodo_ruler", last=True, config={"periodo_authority_id": periodo_authority_id, "supp_list": supp_list_per}) 
nlp.add_pipe("fish_archobjects_ruler", last=True, config={"supp_list": supp_list_obj, "stop_list": stop_list_obj}) 
nlp.add_pipe("fish_monument_types_ruler", last=True, config={"supp_list": supp_list_mon, "stop_list": stop_list_mon})   
#nlp.add_pipe("negation_ruler", last=True) 
nlp.add_pipe("child_span_remover", last=True) 

input_directory = "./data/oasis/journals_july_2024/text extraction - new"

# subset of files to process
file_names = [
    "120_031_097_new.txt",
    "2022_96_001_012_cooper_garton_new.txt",
    "2022_96_013-068_huxley_new.txt",
    "archael547-005-040-breeze_new.txt",
    "archael547-079-116-ceolwulf_new.txt",
    "daj_v023_1901_040-047_new.txt",
    "daj_v086_1966_031-053_new.txt",
    "nas_20_1985_67-86_jackson_new.txt",
    "nas_20_1985_87-112_taylor_new.txt",
    "surreyac103_063-090_lambert_new.txt"
]

# timestamp for use in directory names
timestamp = DT.now().strftime('%Y%m%d')   

# create output file path if it does not already exist
output_directory = os.path.join(input_directory, f"ner-output-{timestamp}")
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

counter = 0
print("scanning input file directory")
for entry in os.scandir(input_directory):
    
    #if entry.is_file() and entry.name.endswith(".txt"): 
    if entry.is_file() and entry.name.lower() in file_names:  
        counter += 1
        # temp break for testing
        #if counter > 3: 
            #break  
            
        ts_started = DT.now()   

        # print progress indicator
        input_file_name = entry.name        
        print(f"processing entry {counter} - '{input_file_name}'")

        # read text contents of input file
        print(f"reading {input_file_name}")
        input_file_text = ""
        with open(entry.path) as input_file:
            input_file_text = input_file.read()
        print(f"read '{input_file_name}' in {DT.now() - ts_started}ms")
        
        # set up metadata to include in output
        metadata = {
            "identifier": input_file_name,
            "title": "vocabulary-based NER results",
            "description": "vocabulary-based NER annotation on report full-text",
            "creator": "T4-1-2-NER-OASIS-reports-full-text.ipynb",
            "periodo_authority_id": periodo_authority_id,
            "ner_pipeline": nlp.pipe_names,
            "input_file_name": input_file_name,
            "input_record_count": 1
        }

        # perform annotation on input text
        ts_nlp = DT.now() 
        print("running nlp pipeline") 
        doc = nlp(input_file_text)
        print(f"finished nlp pipeline in {DT.now() - ts_nlp}")

        ts_sum = DT.now() 
        print("summarizing results") 
        summary = DocSummary(doc, metadata=metadata)
        print(f"finished summarizing results in {DT.now() - ts_sum}")
        
        ts_finished = DT.now()
        metadata["starting"] = ts_started.strftime('%Y-%m-%dT%H:%M:%SZ')
        metadata["finished"] = ts_finished.strftime('%Y-%m-%dT%H:%M:%SZ')
        metadata["duration"] =  ts_finished - ts_started

        # write results to text files
        #html_file_name = os.path.join(output_directory, f"ner-output-{slugify(input_file_name)}.html") 
        #text_file_name = os.path.join(output_directory, f"ner-output-{slugify(input_file_name)}.txt")
        json_file_name = os.path.join(output_directory, f"ner-output-{slugify(input_file_name)}.json")
        pdf_file_name= os.path.join(output_directory, f"ner-output-{slugify(input_file_name)}.pdf")
        
        # note last run took 21 mins for 2 files
        # 10/07/25 - now 1:10:31 for 10 files (JSON, TEXT and HTML output)
        ts_started = DT.now()   
        print("creating PDF report")
        report = summary.report(format="html")
        HTML(None, string=report, encoding="utf-8").write_pdf(target=pdf_file_name)                
        print(f"finished creating PDF report in {DT.now() - ts_started}")

        #ts_started = DT.now()
        #print("creating TEXT report")
        #report = summary.report(format="text")
        #with open(text_file_name, "w") as file:
            #file.write(report)
        #print(f"finished creating TEXT report in {DT.now() - ts_started}")
             
        ts_started = DT.now()
        print("creating JSON report")
        report = summary.report(format="json")
        with open(json_file_name, "w") as file:
            file.write(report) 
        print(f"finished creating JSON report in {DT.now() - ts_started}")
# Out:
# loading spacy language model
# ..done
# adding attribute ruler
# ..done
# reading supplementary lists and stopword lists
# ..done
# Create VocabularyRuler - stop list:
# []
# Stop IDs: []
# Create VocabularyRuler - stop list:
# [{'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/139085', 'term': 'Coin (Contemporary Imitation)'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/139087', 'term': 'Coin (Modern Forgery)'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/139086', 'term': 'Coin (Modern Imitation)'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95353', 'term': 'level'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95306', 'term': 'scale'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96615', 'term': 'shift'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96379', 'term': 'point'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/143243', 'term': 'setting'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96735', 'term': 'staff'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/100151', 'term': 'paper'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96473', 'term': 'model'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/100107', 'term': 'desk'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95183', 'term': 'crest'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/97552', 'term': 'core'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95392', 'term': 'plan'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96677', 'term': 'case'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95374', 'term': 'document'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96364', 'term': 'bucket'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96804', 'term': 'spit'}, {'id': 'http://purl.org/heritagedata/schemes/mda_obj/concepts/170044', 'term': 'lighter'}]
# Stop IDs: ['http://purl.org/heritagedata/schemes/mda_obj/concepts/139085', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/139087', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/139086', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95353', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95306', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96615', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96379', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/143243', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96735', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/100151', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96473', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/100107', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95183', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/97552', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95392', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96677', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/95374', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96364', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/96804', 'http://purl.org/heritagedata/schemes/mda_obj/concepts/170044']
# Create VocabularyRuler - stop list:
# [{'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/71054', 'term': 'Roundhouse (Lock Up)'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/93179', 'term': 'Roundhouse (Railway)'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/69434', 'term': 'works'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/92230', 'term': 'term'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/93931', 'term': 'model'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/88215', 'term': 'half moon'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68762', 'term': 'crest'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/140783', 'term': 'SIGN'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/102972', 'term': 'BARRIER'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/70412', 'term': 'SITE'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68917', 'term': 'TRENCH'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/69434', 'term': 'WORKS'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68866', 'term': 'FIELDWORK'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/70121', 'term': 'CAMERA'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91355', 'term': 'CAR PARK'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/70232', 'term': 'LIFT'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68543', 'term': 'AGRICULTURE AND SUBSISTENCE'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/147336', 'term': 'WINTER BEE HOUSE'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/71635', 'term': 'COACHING INN STABLE'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/87920', 'term': 'MULTI STOREY STABLE'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/70484', 'term': 'COMBINATION FARM BUILDING'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91579', 'term': 'COMBINATION BARN'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/163019', 'term': 'DEER SHED'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/93169', 'term': 'ROOT ROOM'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91992', 'term': 'FOOD AND DRINK PROCESSING SITE'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91922', 'term': 'FERNERY (GLASSHOUSE)'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68629', 'term': 'BROAD RIDGE AND FURROW'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68630', 'term': 'NARROW RIDGE AND FURROW'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68631', 'term': 'STEAM PLOUGHED RIG'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91913', 'term': 'FARMYARD CAUSEWAY'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91955', 'term': 'FISHING SITE'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/139129', 'term': 'DEER COURSE'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162614', 'term': 'LOOSE COURTYARD PLAN'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162615', 'term': 'LOOSE COURTYARD PLAN (FOUR SIDED)'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162616', 'term': 'LOOSE COURTYARD PLAN (ONE SIDED)'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162617', 'term': 'LOOSE COURTYARD PLAN (THREE SIDED)'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162618', 'term': 'LOOSE COURTYARD PLAN (TWO SIDED)'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162619', 'term': 'REGULAR COURTYARD PLAN'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162620', 'term': 'REGULAR COURTYARD E PLAN'}, {'id': 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162621', 'term': 'REGULAR COURTYARD F PLAN'}, {'id': 'http://purl.org/heritag ...
# Stop IDs: ['http://purl.org/heritagedata/schemes/eh_tmt2/concepts/71054', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/93179', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/69434', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/92230', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/93931', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/88215', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68762', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/140783', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/102972', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/70412', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68917', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/69434', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68866', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/70121', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91355', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/70232', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68543', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/147336', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/71635', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/87920', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/70484', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91579', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/163019', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/93169', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91992', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91922', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68629', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68630', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/68631', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91913', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/91955', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/139129', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162614', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162615', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162616', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162617', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162618', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162619', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162620', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162621', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162622', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162623', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162624', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162625', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162626', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162627', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162628', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162629', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162630', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162631', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162632', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162633', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162636', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/78214', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/162645', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/144474', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/160452', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/71455', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/159391', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/92363', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/92364', 'http://purl.org/heritagedata/schemes/eh_tmt2/concepts/92453', 'http://purl.org/heritagedata/schemes/eh_tmt2/concept ...
# scanning input file directory
# processing entry 1 - '120_031_097_new.txt'
# reading 120_031_097_new.txt
# read '120_031_097_new.txt' in 0:00:00.037481ms
# running nlp pipeline
# finished nlp pipeline in 0:03:02.986133
# summarizing results
# finished summarizing results in 0:00:00.000042
# creating PDF report
# "_get_dependency_pairs" ran in 87.530 seconds
# "_get_noun_chunk_pairs" ran in 12.002 seconds
# "_get_all_pairs" ran in 99.533 seconds
# "get_span_pairs" ran in 99.533 seconds
# "_get_dependency_pairs" ran in 85.314 seconds
# "_get_noun_chunk_pairs" ran in 9.244 seconds
# "_get_all_pairs" ran in 94.558 seconds
# "get_negated_span_pairs" ran in 94.558 seconds
# "report_to_html" ran in 197.334 seconds
# "report" ran in 197.334 seconds
# finished creating PDF report in 0:03:26.338211
# creating JSON report
# "report_to_json" ran in 0.690 seconds
# "report" ran in 0.690 seconds
# finished creating JSON report in 0:00:00.693958
# processing entry 2 - 'surreyac103_063-090_lambert_new.txt'
# reading surreyac103_063-090_lambert_new.txt
# read 'surreyac103_063-090_lambert_new.txt' in 0:00:00.002850ms
# running nlp pipeline
# finished nlp pipeline in 0:00:58.110518
# summarizing results
# finished summarizing results in 0:00:00.005270
# creating PDF report
# "_get_dependency_pairs" ran in 22.819 seconds
# "_get_noun_chunk_pairs" ran in 2.405 seconds
# "_get_all_pairs" ran in 25.225 seconds
# "get_span_pairs" ran in 25.225 seconds
# "_get_dependency_pairs" ran in 22.895 seconds
# "_get_noun_chunk_pairs" ran in 2.315 seconds
# "_get_all_pairs" ran in 25.210 seconds
# "get_negated_span_pairs" ran in 25.210 seconds
# "report_to_html" ran in 51.262 seconds
# "report" ran in 51.262 seconds
# finished creating PDF report in 0:00:58.508553
# creating JSON report
# "report_to_json" ran in 0.084 seconds
# "report" ran in 0.084 seconds
# finished creating JSON report in 0:00:00.085019
# processing entry 3 - 'DAJ_v086_1966_031-053_new.txt'
# reading DAJ_v086_1966_031-053_new.txt
# read 'DAJ_v086_1966_031-053_new.txt' in 0:00:00.001700ms
# running nlp pipeline
# finished nlp pipeline in 0:00:33.975420
# summarizing results
# finished summarizing results in 0:00:00.001531
# creating PDF report
# "_get_dependency_pairs" ran in 7.339 seconds
# "_get_noun_chunk_pairs" ran in 0.755 seconds
# "_get_all_pairs" ran in 8.095 seconds
# "get_span_pairs" ran in 8.095 seconds
# "_get_dependency_pairs" ran in 7.450 seconds
# "_get_noun_chunk_pairs" ran in 0.761 seconds
# "_get_all_pairs" ran in 8.212 seconds
# "get_negated_span_pairs" ran in 8.212 seconds
# "report_to_html" ran in 16.588 seconds
# "report" ran in 16.588 seconds
# finished creating PDF report in 0:00:20.503526
# creating JSON report
# "report_to_json" ran in 0.073 seconds
# "report" ran in 0.073 seconds
# finished creating JSON report in 0:00:00.073961
# processing entry 4 - 'archael547-079-116-ceolwulf_new.txt'
# reading archael547-079-116-ceolwulf_new.txt
# read 'archael547-079-116-ceolwulf_new.txt' in 0:00:01.083451ms
# running nlp pipeline
# finished nlp pipeline in 0:01:53.534061
# summarizing results
# finished summarizing results in 0:00:00.000067
# creating PDF report
# "_get_dependency_pairs" ran in 35.873 seconds
# "_get_noun_chunk_pairs" ran in 4.468 seconds
# "_get_all_pairs" ran in 40.341 seconds
# "get_span_pairs" ran in 40.341 seconds
# "_get_dependency_pairs" ran in 36.105 seconds
# "_get_noun_chunk_pairs" ran in 4.386 seconds
# "_get_all_pairs" ran in 40.491 seconds
# "get_negated_span_pairs" ran in 40.491 seconds
# "report_to_html" ran in 82.162 seconds
# "report" ran in 82.162 seconds
# finished creating PDF report in 0:01:28.637650
# creating JSON report
# "report_to_json" ran in 0.156 seconds
# "report" ran in 0.156 seconds
# finished creating JSON report in 0:00:00.157306
# processing entry 5 - 'NAS_20_1985_67-86_Jackson_new.txt'
# reading NAS_20_1985_67-86_Jackson_new.txt
# read 'NAS_20_1985_67-86_Jackson_new.txt' in 0:00:00.000353ms
# running nlp pipeline
# finished nlp pipeline in 0:00:40.859401
# summarizing results
# finished summarizing results in 0:00:00.006001
# creating PDF report
# "_get_dependency_pairs" ran in 10.877 seconds
# "_get_noun_chunk_pairs" ran in 1.092 seconds
# "_get_all_pairs" ran in 11.969 seconds
# "get_span_pairs" ran in 11.969 seconds
# "_get_dependency_pairs" ran in 10.935 seconds
# "_get_noun_chunk_pairs" ran in 1.108 seconds
# "_get_all_pairs" ran in 12.044 seconds
# "get_negated_span_pairs" ran in 12.044 seconds
# "report_to_html" ran in 24.409 seconds
# "report" ran in 24.409 seconds
# finished creating PDF report in 0:00:29.363772
# creating JSON report
# "report_to_json" ran in 0.063 seconds
# "report" ran in 0.063 seconds
# finished creating JSON report in 0:00:00.064063
# processing entry 6 - '2022_96_001_012_Cooper_Garton_new.txt'
# reading 2022_96_001_012_Cooper_Garton_new.txt
# read '2022_96_001_012_Cooper_Garton_new.txt' in 0:00:00.063705ms
# running nlp pipeline
# finished nlp pipeline in 0:00:18.158729
# summarizing results
# finished summarizing results in 0:00:00.001322
# creating PDF report
# "_get_dependency_pairs" ran in 2.502 seconds
# "_get_noun_chunk_pairs" ran in 0.310 seconds
# "_get_all_pairs" ran in 2.812 seconds
# "get_span_pairs" ran in 2.812 seconds
# "_get_dependency_pairs" ran in 2.505 seconds
# "_get_noun_chunk_pairs" ran in 0.277 seconds
# "_get_all_pairs" ran in 2.782 seconds
# "get_negated_span_pairs" ran in 2.782 seconds
# "report_to_html" ran in 5.697 seconds
# "report" ran in 5.697 seconds
# finished creating PDF report in 0:00:08.419864
# creating JSON report
# "report_to_json" ran in 0.029 seconds
# "report" ran in 0.029 seconds
# finished creating JSON report in 0:00:00.029879
# processing entry 7 - 'archael547-005-040-breeze_new.txt'
# reading archael547-005-040-breeze_new.txt
# read 'archael547-005-040-breeze_new.txt' in 0:00:00.001607ms
# running nlp pipeline
# finished nlp pipeline in 0:01:45.659657
# summarizing results
# finished summarizing results in 0:00:00.000076
# creating PDF report
# "_get_dependency_pairs" ran in 58.825 seconds
# "_get_noun_chunk_pairs" ran in 6.798 seconds
# "_get_all_pairs" ran in 65.623 seconds
# "get_span_pairs" ran in 65.623 seconds
# "_get_dependency_pairs" ran in 57.847 seconds
# "_get_noun_chunk_pairs" ran in 6.834 seconds
# "_get_all_pairs" ran in 64.681 seconds
# "get_negated_span_pairs" ran in 64.681 seconds
# "report_to_html" ran in 132.712 seconds
# "report" ran in 132.712 seconds
# finished creating PDF report in 0:02:20.360377
# creating JSON report
# "report_to_json" ran in 0.145 seconds
# "report" ran in 0.145 seconds
# finished creating JSON report in 0:00:00.146700
# processing entry 8 - '2022_96_013-068_Huxley_new.txt'
# reading 2022_96_013-068_Huxley_new.txt
# read '2022_96_013-068_Huxley_new.txt' in 0:00:01.057938ms
# running nlp pipeline
# finished nlp pipeline in 0:01:22.345760
# summarizing results
# finished summarizing results in 0:00:00.001598
# creating PDF report
# "_get_dependency_pairs" ran in 73.741 seconds
# "_get_noun_chunk_pairs" ran in 8.298 seconds
# "_get_all_pairs" ran in 82.040 seconds
# "get_span_pairs" ran in 82.040 seconds
# "_get_dependency_pairs" ran in 74.672 seconds
# "_get_noun_chunk_pairs" ran in 8.211 seconds
# "_get_all_pairs" ran in 82.884 seconds
# "get_negated_span_pairs" ran in 82.884 seconds
# "report_to_html" ran in 167.871 seconds
# "report" ran in 167.871 seconds
# finished creating PDF report in 0:03:00.893966
# creating JSON report
# "report_to_json" ran in 0.124 seconds
# "report" ran in 0.124 seconds
# finished creating JSON report in 0:00:00.125560
# processing entry 9 - 'NAS_20_1985_87-112_Taylor_new.txt'
# reading NAS_20_1985_87-112_Taylor_new.txt
# read 'NAS_20_1985_87-112_Taylor_new.txt' in 0:00:00.000727ms
# running nlp pipeline
# finished nlp pipeline in 0:00:56.272589
# summarizing results
# finished summarizing results in 0:00:00.000111
# creating PDF report
# "_get_dependency_pairs" ran in 21.001 seconds
# "_get_noun_chunk_pairs" ran in 2.107 seconds
# "_get_all_pairs" ran in 23.109 seconds
# "get_span_pairs" ran in 23.109 seconds
# "_get_dependency_pairs" ran in 21.043 seconds
# "_get_noun_chunk_pairs" ran in 2.233 seconds
# "_get_all_pairs" ran in 23.276 seconds
# "get_negated_span_pairs" ran in 23.276 seconds
# "report_to_html" ran in 47.166 seconds
# "report" ran in 47.166 seconds
# finished creating PDF report in 0:00:53.749011
# creating JSON report
# "report_to_json" ran in 0.083 seconds
# "report" ran in 0.083 seconds
# finished creating JSON report in 0:00:00.084091
# processing entry 10 - 'DAJ_v023_1901_040-047_new.txt'
# reading DAJ_v023_1901_040-047_new.txt
# read 'DAJ_v023_1901_040-047_new.txt' in 0:00:00.000266ms
# running nlp pipeline
# finished nlp pipeline in 0:00:12.665756
# summarizing results
# finished summarizing results in 0:00:00.004155
# creating PDF report
# "_get_dependency_pairs" ran in 0.567 seconds
# "_get_noun_chunk_pairs" ran in 0.060 seconds
# "_get_all_pairs" ran in 0.627 seconds
# "get_span_pairs" ran in 0.627 seconds
# "_get_dependency_pairs" ran in 0.564 seconds
# "_get_noun_chunk_pairs" ran in 0.074 seconds
# "_get_all_pairs" ran in 0.639 seconds
# "get_negated_span_pairs" ran in 0.639 seconds
# "report_to_html" ran in 1.331 seconds
# "report" ran in 1.331 seconds
# finished creating PDF report in 0:00:02.803284
# creating JSON report
# "report_to_json" ran in 0.020 seconds
# "report" ran in 0.020 seconds
# finished creating JSON report in 0:00:00.019989
